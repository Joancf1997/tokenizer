# %% [markdown]
# # Tokenizer
#
# This notebook is based on the course ofered by Andrej Karpathy: https://www.youtube.com/watch?v=zduSFxRajkE&t=4708s

# %% [markdown]
# Tokenization web app: https://tiktokenizer.vercel.app/

# %%
[ord(x) for x in "안녕하세요 👋 (hello in Korean!)"]
# Out:
# [50504,
#  45397,
#  54616,
#  49464,
#  50836,
#  32,
#  128075,
#  32,
#  40,
#  104,
#  101,
#  108,
#  108,
#  111,
#  32,
#  105,
#  110,
#  32,
#  75,
#  111,
#  114,
#  101,
#  97,
#  110,
#  33,
#  41]

# %%
list("안녕하세요 👋 (hello in Korean!)".encode("utf-8"))
# Out:
# [236,
#  149,
#  136,
#  235,
#  133,
#  149,
#  237,
#  149,
#  152,
#  236,
#  132,
#  184,
#  236,
#  154,
#  148,
#  32,
#  240,
#  159,
#  145,
#  139,
#  32,
#  40,
#  104,
#  101,
#  108,
#  108,
#  111,
#  32,
#  105,
#  110,
#  32,
#  75,
#  111,
#  114,
#  101,
#  97,
#  110,
#  33,
#  41]

# %%
# text from https://www.reedbeta.com/blog/programmers-intro-to-unicode/
text = "Ｕｎｉｃｏｄｅ! 🅤🅝🅘🅒🅞🅓🅔‽ 🇺‌🇳‌🇮‌🇨‌🇴‌🇩‌🇪! 😄 The very name strikes fear and awe into the hearts of programmers worldwide. We all know we ought to “support Unicode” in our software (whatever that means—like using wchar_t for all the strings, right?). But Unicode can be abstruse, and diving into the thousand-page Unicode Standard plus its dozens of supplementary annexes, reports, and notes can be more than a little intimidating. I don’t blame programmers for still finding the whole thing mysterious, even 30 years after Unicode’s inception."

#Encode 
tokens = text.encode("utf-8")
tokens = list(map(int, tokens)) # convert to a list of integers in range 0..255

# %%
print('---')
print(text)
print("length:", len(text))
print('---')
print(tokens)
print("length:", len(tokens))
# Out:
# ---
# Ｕｎｉｃｏｄｅ! 🅤🅝🅘🅒🅞🅓🅔‽ 🇺‌🇳‌🇮‌🇨‌🇴‌🇩‌🇪! 😄 The very name strikes fear and awe into the hearts of programmers worldwide. We all know we ought to “support Unicode” in our software (whatever that means—like using wchar_t for all the strings, right?). But Unicode can be abstruse, and diving into the thousand-page Unicode Standard plus its dozens of supplementary annexes, reports, and notes can be more than a little intimidating. I don’t blame programmers for still finding the whole thing mysterious, even 30 years after Unicode’s inception.
# length: 533
# ---
# ...

# %%
# Function to get the pair of consecutive tokens
def get_stats(ids):
  counts = {}
  for pair in zip(ids, ids[1:]):
      counts[pair] = counts.get(pair, 0) + 1
  return counts

# %%
stats = get_stats(tokens)
print(stats)
print(sorted(((v,k) for k,v in stats.items()), reverse=True))
# Out:
# {(239, 188): 1, (188, 181): 1, (181, 239): 1, (239, 189): 6, (189, 142): 1, (142, 239): 1, (189, 137): 1, (137, 239): 1, (189, 131): 1, (131, 239): 1, (189, 143): 1, (143, 239): 1, (189, 132): 1, (132, 239): 1, (189, 133): 1, (133, 33): 1, (33, 32): 2, (32, 240): 3, (240, 159): 15, (159, 133): 7, (133, 164): 1, (164, 240): 1, (133, 157): 1, (157, 240): 1, (133, 152): 1, (152, 240): 1, (133, 146): 1, (146, 240): 1, (133, 158): 1, (158, 240): 1, (133, 147): 1, (147, 240): 1, (133, 148): 1, (148, 226): 1, (226, 128): 12, (128, 189): 1, (189, 32): 1, (159, 135): 7, (135, 186): 1, (186, 226): 1, (128, 140): 6, (140, 240): 6, (135, 179): 1, (179, 226): 1, (135, 174): 1, (174, 226): 1, (135, 168): 1, (168, 226): 1, (135, 180): 1, (180, 226): 1, (135, 169): 1, (169, 226): 1, (135, 170): 1, (170, 33): 1, (159, 152): 1, (152, 132): 1, (132, 32): 1, (32, 84): 1, (84, 104): 1, (104, 101): 6, (101, 32): 20, (32, 118): 1, (118, 101): 3, (101, 114): 6, (114, 121): 2, (121, 32): 2, (32, 110): 2, (11
# ...

# %%
# This is the pair of tockens that appears most frequently.
# We can add a new token representing this pair to our vocabulary.
top_pair = max(stats, key=stats.get)
top_pair
# Out:
# (101, 32)

# %%
# Function to merge the most frequent pair given the text tokens
def merge(ids, pair, idx):
  newids = []
  i = 0
  while i < len(ids):
    if i < len(ids) - 1 and ids[i] == pair[0] and ids[i+1] == pair[1]:
      newids.append(idx)
      i += 2
    else:
      newids.append(ids[i])
      i += 1
  return newids

# %%
# text, max_pair, new token index
print(merge([5,6,6,7,9,1], (6, 7), 99))
# Out:
# [5, 6, 99, 9, 1]

# %%
# Merge the current text with the new one 
tokens2 = merge(tokens, top_pair, 256)
print(tokens2)
print("length:", len(tokens2))
# Out:
# [239, 188, 181, 239, 189, 142, 239, 189, 137, 239, 189, 131, 239, 189, 143, 239, 189, 132, 239, 189, 133, 33, 32, 240, 159, 133, 164, 240, 159, 133, 157, 240, 159, 133, 152, 240, 159, 133, 146, 240, 159, 133, 158, 240, 159, 133, 147, 240, 159, 133, 148, 226, 128, 189, 32, 240, 159, 135, 186, 226, 128, 140, 240, 159, 135, 179, 226, 128, 140, 240, 159, 135, 174, 226, 128, 140, 240, 159, 135, 168, 226, 128, 140, 240, 159, 135, 180, 226, 128, 140, 240, 159, 135, 169, 226, 128, 140, 240, 159, 135, 170, 33, 32, 240, 159, 152, 132, 32, 84, 104, 256, 118, 101, 114, 121, 32, 110, 97, 109, 256, 115, 116, 114, 105, 107, 101, 115, 32, 102, 101, 97, 114, 32, 97, 110, 100, 32, 97, 119, 256, 105, 110, 116, 111, 32, 116, 104, 256, 104, 101, 97, 114, 116, 115, 32, 111, 102, 32, 112, 114, 111, 103, 114, 97, 109, 109, 101, 114, 115, 32, 119, 111, 114, 108, 100, 119, 105, 100, 101, 46, 32, 87, 256, 97, 108, 108, 32, 107, 110, 111, 119, 32, 119, 256, 111, 117, 103, 104, 116, 32, 116, 111, 32, 226, 128, 1
# ...

# %% [markdown]
# # Proceed to merge the current vocab

# %%
vocab_size = 276 # the desired final vocabulary size
num_merges = vocab_size - 256
ids = list(tokens) # copy so we don't destroy the original list

# %%
merges = {}

for i in range(num_merges):
  stats = get_stats(ids) # get pair frequencies
  pair = max(stats, key=stats.get) # get the most frequent pair
  idx = 256 + 1
  print(f"merging {pair} into a new token {idx}")
  ids = merge(ids, pair, idx)
  merges[pair] = idx
# Out:
# merging (101, 32) into a new token 257
# merging (240, 159) into a new token 257
# merging (226, 128) into a new token 257
# merging (105, 110) into a new token 257
# merging (115, 32) into a new token 257
# merging (97, 110) into a new token 257
# merging (32, 257) into a new token 257
# merging (116, 104) into a new token 257
# merging (257, 257) into a new token 257
# merging (257, 133) into a new token 257
# merging (257, 135) into a new token 257
# merging (97, 114) into a new token 257
# merging (101, 257) into a new token 257
# merging (257, 100) into a new token 257
# merging (257, 257) into a new token 257
# merging (257, 32) into a new token 257
# merging (239, 189) into a new token 257
# merging (257, 140) into a new token 257
# merging (257, 257) into a new token 257
# merging (101, 114) into a new token 257

# %%
print("tokens length:", len(tokens))
print("ids length:", len(ids))
print(f"compression ratio: {len(tokens) / len(ids):.2f}X")
# Out:
# tokens length: 616
# ids length: 433
# compression ratio: 1.42X

# %% [markdown]
# ## With this vocab, we can proceed to encode and decode text

# %% [markdown]
# ## Decoding

# %%
vocab = {idx: bytes([idx]) for idx in range(256)}
for (p0, p1), idx in merges.items():
    vocab[idx] = vocab[p0] + vocab[p1]

def decode(ids):
  # given ids (list of integers), return Python string
  tokens = b"".join(vocab[idx] for idx in ids)
  text = tokens.decode("utf-8", errors="replace")
  return text

print(decode([128]))
# Out:
# �

# %% [markdown]
# ## Encoding

# %%
def encode(text):
  # given a string, return list of integers (the tokens)
  tokens = list(text.encode("utf-8"))
  while len(tokens) >= 2:
    stats = get_stats(tokens)
    pair = min(stats, key=lambda p: merges.get(p, float("inf")))
    if pair not in merges:
      break # nothing else can be merged
    idx = merges[pair]
    tokens = merge(tokens, pair, idx)
  return tokens

print(encode(""))
# Out:
# []

# %%
# Encoding and decoding test
print(decode(encode("hello world")))
# Out:
# hello world

# %%
text = "hello world"
text2 = decode(encode("hello world"))
print(text2 == text)
# Out:
# True
